# %% [markdown]
# # Import necessary libraries

# %%
import requests 
import re
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %% [markdown]
# # Raw Data

# %%
cameras=pd.read_csv(r"C:\Users\DELL\Downloads\cameras.csv")

# %%
cameras
# Out:
#         Brand  Pixels                                         Resolution  \
# 0       SJCAM    16.0  1080 FHD 1920*1080 720p 1280*720 60fps 720p 12...
# 1       SJCAM    12.0                                          1920X1080
# 2    Insta360     NaN                                        3840 x 2160
# 3       GoPro    23.0                     Video 5.3K60 + 4K120, Wide FOV
# 4       SJCAM     5.0                                                NaN
# ..        ...     ...                                                ...
# 634    AVOIHS     8.0                                                720
# 635     Bzrqx    12.0                                         1920*1080p
# 636    CALLIE    16.0                                           108*1080
# 637    AVOIHS     8.0                                                720
# 638    VOLTAC    16.0                                                 4K
#
#          Quality                                  Frames per second  \
# 0       1080 FHD                           30 fps fpsVideo FormatMO
# 1          1080p                    30 fps fpsVideo FormatMOVOther
# 2           5.7K                                             30 fps
# 3       5.3K, 4K                                             60 fps
# 4    1080Full HD  30FPS fpsVideo FormatM-JPEGOther Video Feature...
# ..           ...                                                ...
# 634           HD                                30 fpsVideo FormatA
# 635   1920*1080p                                             30 fps
# 636           HD                                             40 fps
# 637           HD                                30 fpsVideo FormatA
# 638           4K                                30 fpsVideo FormatA
#
#        Shutter Sensor size       Color  \
# 0         Auto       1/3.2       Black
# 1    AutoOther       1/2.3       Black
# 2         Auto         NaN       Black
# 3         Auto       1/2.3       Black
# 4         Auto         NaN        Blue
# ..         ...         ...         ...
# 634      Fixed         NaN  Multicolor
# 635      Fixed         NaN       Black
# 636       Auto         NaN       Black
# 637      Fixed         NaN  Multicolor
# 638       Auto         NaN       Black
#
#                                        Camera size  \
# 0                                              NaN
# 1                                              NaN
# 2     ('4.62 cm', '11.3 cm', '2.8 cm', '0.149 kg')
# 3    ('7.18 cm', '5.08 cm', '3.36 cm', '0.131 kg')
# 4                                              NaN
# ..                                             ...
# 634                                            NaN
# 635                                            NaN
# 636                                            NaN
# 637                                            NaN
# 638                                            NaN
#
#                                         Shooting modes    Price
# 0    VideoLapse, PhotoLapse, Burst mode, Car mode, ...   ₹4,399
# 1    Auto, ManualPortsType-C Port, HDMI Port, SD Ca...   ₹5,699
# 2    Still, VideoPortsType-CWireless ConnectivityYe...  ₹34,990
# 3          Super Photo, HDR, Standard and RAWPortsHDMI  ₹27,490
# 4    AutoPortsHDMIOptical ZoomFixed FocusDigital Zo...   ₹2,299
# ..                                                 ...      ...
# 634                                          HDPortsNA     ₹899
# 635           1920*1080pPorts1Wireless ConnectivityYes   ₹2,499
# 636                                      runningPorts2   ₹1,363
# 637                                          HDPortsNA     ₹899
# 638  MOV,JPGPorts1Wireless ConnectivityYesSupported...   ₹1,899
#
# [639 rows x 11 columns]

# %%
cameras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 639 entries, 0 to 638
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              594 non-null    object
#  1   Pixels             604 non-null    float64
#  2   Resolution         593 non-null    object
#  3   Quality            618 non-null    object
#  4   Frames per second  631 non-null    object
#  5   Shutter            631 non-null    object
#  6   Sensor size        97 non-null     object
#  7   Color              616 non-null    object
#  8   Camera size        511 non-null    object
#  9   Shooting modes     631 non-null    object
#  10  Price              639 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 55.0+ KB

# %%
data=cameras.copy()

# %%
data
# Out:
#         Brand  Pixels                                         Resolution  \
# 0       SJCAM    16.0  1080 FHD 1920*1080 720p 1280*720 60fps 720p 12...
# 1       SJCAM    12.0                                          1920X1080
# 2    Insta360     NaN                                        3840 x 2160
# 3       GoPro    23.0                     Video 5.3K60 + 4K120, Wide FOV
# 4       SJCAM     5.0                                                NaN
# ..        ...     ...                                                ...
# 634    AVOIHS     8.0                                                720
# 635     Bzrqx    12.0                                         1920*1080p
# 636    CALLIE    16.0                                           108*1080
# 637    AVOIHS     8.0                                                720
# 638    VOLTAC    16.0                                                 4K
#
#          Quality                                  Frames per second  \
# 0       1080 FHD                           30 fps fpsVideo FormatMO
# 1          1080p                    30 fps fpsVideo FormatMOVOther
# 2           5.7K                                             30 fps
# 3       5.3K, 4K                                             60 fps
# 4    1080Full HD  30FPS fpsVideo FormatM-JPEGOther Video Feature...
# ..           ...                                                ...
# 634           HD                                30 fpsVideo FormatA
# 635   1920*1080p                                             30 fps
# 636           HD                                             40 fps
# 637           HD                                30 fpsVideo FormatA
# 638           4K                                30 fpsVideo FormatA
#
#        Shutter Sensor size       Color  \
# 0         Auto       1/3.2       Black
# 1    AutoOther       1/2.3       Black
# 2         Auto         NaN       Black
# 3         Auto       1/2.3       Black
# 4         Auto         NaN        Blue
# ..         ...         ...         ...
# 634      Fixed         NaN  Multicolor
# 635      Fixed         NaN       Black
# 636       Auto         NaN       Black
# 637      Fixed         NaN  Multicolor
# 638       Auto         NaN       Black
#
#                                        Camera size  \
# 0                                              NaN
# 1                                              NaN
# 2     ('4.62 cm', '11.3 cm', '2.8 cm', '0.149 kg')
# 3    ('7.18 cm', '5.08 cm', '3.36 cm', '0.131 kg')
# 4                                              NaN
# ..                                             ...
# 634                                            NaN
# 635                                            NaN
# 636                                            NaN
# 637                                            NaN
# 638                                            NaN
#
#                                         Shooting modes    Price
# 0    VideoLapse, PhotoLapse, Burst mode, Car mode, ...   ₹4,399
# 1    Auto, ManualPortsType-C Port, HDMI Port, SD Ca...   ₹5,699
# 2    Still, VideoPortsType-CWireless ConnectivityYe...  ₹34,990
# 3          Super Photo, HDR, Standard and RAWPortsHDMI  ₹27,490
# 4    AutoPortsHDMIOptical ZoomFixed FocusDigital Zo...   ₹2,299
# ..                                                 ...      ...
# 634                                          HDPortsNA     ₹899
# 635           1920*1080pPorts1Wireless ConnectivityYes   ₹2,499
# 636                                      runningPorts2   ₹1,363
# 637                                          HDPortsNA     ₹899
# 638  MOV,JPGPorts1Wireless ConnectivityYesSupported...   ₹1,899
#
# [639 rows x 11 columns]

# %% [markdown]
# # Data Cleaning

# %%
data['Sensor size']=data['Sensor size'].replace({np.nan:0,'1/3.2':1/3.2,'1/2.3':1/2.3,'1/1.7':1/1.7,'1/1.2':1/1.2,'27.6':27.6,'1080':1.08,'1/2.9':1/2.9,'576':5.76})

# %%
data['Sensor size'].unique()
# Out:
# array([ 0.3125    ,  0.43478261,  0.        ,  0.58823529,  0.83333333,
#         1.08      ,  0.34482759, 27.6       ,  5.76      ])

# %%
data.astype({'Sensor size':np.float})
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_8172/2760342771.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data.astype({'Sensor size':np.float})
#         Brand  Pixels                                         Resolution  \
# 0       SJCAM    16.0  1080 FHD 1920*1080 720p 1280*720 60fps 720p 12...
# 1       SJCAM    12.0                                          1920X1080
# 2    Insta360     NaN                                        3840 x 2160
# 3       GoPro    23.0                     Video 5.3K60 + 4K120, Wide FOV
# 4       SJCAM     5.0                                                NaN
# ..        ...     ...                                                ...
# 634    AVOIHS     8.0                                                720
# 635     Bzrqx    12.0                                         1920*1080p
# 636    CALLIE    16.0                                           108*1080
# 637    AVOIHS     8.0                                                720
# 638    VOLTAC    16.0                                                 4K
#
#          Quality                                  Frames per second  \
# 0       1080 FHD                           30 fps fpsVideo FormatMO
# 1          1080p                    30 fps fpsVideo FormatMOVOther
# 2           5.7K                                             30 fps
# 3       5.3K, 4K                                             60 fps
# 4    1080Full HD  30FPS fpsVideo FormatM-JPEGOther Video Feature...
# ..           ...                                                ...
# 634           HD                                30 fpsVideo FormatA
# 635   1920*1080p                                             30 fps
# 636           HD                                             40 fps
# 637           HD                                30 fpsVideo FormatA
# 638           4K                                30 fpsVideo FormatA
#
#        Shutter  Sensor size       Color  \
# 0         Auto     0.312500       Black
# 1    AutoOther     0.434783       Black
# 2         Auto     0.000000       Black
# 3         Auto     0.434783       Black
# 4         Auto     0.000000        Blue
# ..         ...          ...         ...
# 634      Fixed     0.000000  Multicolor
# 635      Fixed     0.000000       Black
# 636       Auto     0.000000       Black
# 637      Fixed     0.000000  Multicolor
# 638       Auto     0.000000       Black
#
#                                        Camera size  \
# 0                                              NaN
# 1                                              NaN
# 2     ('4.62 cm', '11.3 cm', '2.8 cm', '0.149 kg')
# 3    ('7.18 cm', '5.08 cm', '3.36 cm', '0.131 kg')
# 4                                              NaN
# ..                                             ...
# 634                                            NaN
# 635                                            NaN
# 636                                            NaN
# 637                                            NaN
# 638                                            NaN
#
#                                         Shooting modes    Price
# 0    VideoLapse, PhotoLapse, Burst mode, Car mode, ...   ₹4,399
# 1    Auto, ManualPortsType-C Port, HDMI Port, SD Ca...   ₹5,699
# 2    Still, VideoPortsType-CWireless ConnectivityYe...  ₹34,990
# 3          Super Photo, HDR, Standard and RAWPortsHDMI  ₹27,490
# 4    AutoPortsHDMIOptical ZoomFixed FocusDigital Zo...   ₹2,299
# ..                                                 ...      ...
# 634                                          HDPortsNA     ₹899
# 635           1920*1080pPorts1Wireless ConnectivityYes   ₹2,499
# 636                                      runningPorts2   ₹1,363
# 637                                          HDPortsNA     ₹899
# 638  MOV,JPGPorts1Wireless ConnectivityYesSupported...   ₹1,899
#
# [639 rows x 11 columns]

# %%
data['Price']=data['Price'].str.replace(',','')

# %%
data
# Out:
#         Brand  Pixels                                         Resolution  \
# 0       SJCAM    16.0  1080 FHD 1920*1080 720p 1280*720 60fps 720p 12...
# 1       SJCAM    12.0                                          1920X1080
# 2    Insta360     NaN                                        3840 x 2160
# 3       GoPro    23.0                     Video 5.3K60 + 4K120, Wide FOV
# 4       SJCAM     5.0                                                NaN
# ..        ...     ...                                                ...
# 634    AVOIHS     8.0                                                720
# 635     Bzrqx    12.0                                         1920*1080p
# 636    CALLIE    16.0                                           108*1080
# 637    AVOIHS     8.0                                                720
# 638    VOLTAC    16.0                                                 4K
#
#          Quality                                  Frames per second  \
# 0       1080 FHD                           30 fps fpsVideo FormatMO
# 1          1080p                    30 fps fpsVideo FormatMOVOther
# 2           5.7K                                             30 fps
# 3       5.3K, 4K                                             60 fps
# 4    1080Full HD  30FPS fpsVideo FormatM-JPEGOther Video Feature...
# ..           ...                                                ...
# 634           HD                                30 fpsVideo FormatA
# 635   1920*1080p                                             30 fps
# 636           HD                                             40 fps
# 637           HD                                30 fpsVideo FormatA
# 638           4K                                30 fpsVideo FormatA
#
#        Shutter  Sensor size       Color  \
# 0         Auto     0.312500       Black
# 1    AutoOther     0.434783       Black
# 2         Auto     0.000000       Black
# 3         Auto     0.434783       Black
# 4         Auto     0.000000        Blue
# ..         ...          ...         ...
# 634      Fixed     0.000000  Multicolor
# 635      Fixed     0.000000       Black
# 636       Auto     0.000000       Black
# 637      Fixed     0.000000  Multicolor
# 638       Auto     0.000000       Black
#
#                                        Camera size  \
# 0                                              NaN
# 1                                              NaN
# 2     ('4.62 cm', '11.3 cm', '2.8 cm', '0.149 kg')
# 3    ('7.18 cm', '5.08 cm', '3.36 cm', '0.131 kg')
# 4                                              NaN
# ..                                             ...
# 634                                            NaN
# 635                                            NaN
# 636                                            NaN
# 637                                            NaN
# 638                                            NaN
#
#                                         Shooting modes  Price
# 0    VideoLapse, PhotoLapse, Burst mode, Car mode, ...   4399
# 1    Auto, ManualPortsType-C Port, HDMI Port, SD Ca...   5699
# 2    Still, VideoPortsType-CWireless ConnectivityYe...  34990
# 3          Super Photo, HDR, Standard and RAWPortsHDMI  27490
# 4    AutoPortsHDMIOptical ZoomFixed FocusDigital Zo...   2299
# ..                                                 ...    ...
# 634                                          HDPortsNA    899
# 635           1920*1080pPorts1Wireless ConnectivityYes   2499
# 636                                      runningPorts2   1363
# 637                                          HDPortsNA    899
# 638  MOV,JPGPorts1Wireless ConnectivityYesSupported...   1899
#
# [639 rows x 11 columns]
