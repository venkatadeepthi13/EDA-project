# %% [markdown]
# # Import necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data cleaning

# %%
camera400=pd.read_csv(r"C:\Users\DELL\Downloads\camera400.csv")

# %%
camera400
# Out:
#         Brand  Pixels                                         Resolution  \
# 0    Insta360     NaN                                        3840 x 2160
# 1       GoPro    23.0                     Video 5.3K60 + 4K120, Wide FOV
# 2    Insta360    72.0                                               5.7K
# 3       SJCAM    16.0                                    4K, 1080P, 720P
# 4       GoPro    27.0                                        5120 × 2880
# ..        ...     ...                                                ...
# 395     GoPro    10.0                                         1440, 1080
# 396       dji     0.0                                                NaN
# 397     GoPro     NaN                                        5228 x 2624
# 398     SJCAM    16.0  4K (3840*2160) 30fps, 2.7K (2688*1520) 30fps, ...
# 399     SJCAM    20.0  3840 x 2160p at 30 fps (H.264/AVC, H.265/HEVC,...
#
#                                                Quality  \
# ...

# %%
data=camera400.copy()

# %%
data
# Out:
#         Brand  Pixels                                         Resolution  \
# 0    Insta360     NaN                                        3840 x 2160
# 1       GoPro    23.0                     Video 5.3K60 + 4K120, Wide FOV
# 2    Insta360    72.0                                               5.7K
# 3       SJCAM    16.0                                    4K, 1080P, 720P
# 4       GoPro    27.0                                        5120 × 2880
# ..        ...     ...                                                ...
# 395     GoPro    10.0                                         1440, 1080
# 396       dji     0.0                                                NaN
# 397     GoPro     NaN                                        5228 x 2624
# 398     SJCAM    16.0  4K (3840*2160) 30fps, 2.7K (2688*1520) 30fps, ...
# 399     SJCAM    20.0  3840 x 2160p at 30 fps (H.264/AVC, H.265/HEVC,...
#
#                                                Quality  \
# ...

# %%
data['Sensor size']=data['Sensor size'].replace({np.nan:0,'1/3.2':1/3.2,'1/2.3':1/2.3,'1/1.7':1/1.7,'1/1.2':1/1.2,'27.6':27.6,'1080':1.08,'1/2.9':1/2.9,'576':5.76})

# %%
data.astype({'Sensor size':np.float})
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_22464/2760342771.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data.astype({'Sensor size':np.float})
#         Brand  Pixels                                         Resolution  \
# 0    Insta360     NaN                                        3840 x 2160
# 1       GoPro    23.0                     Video 5.3K60 + 4K120, Wide FOV
# 2    Insta360    72.0                                               5.7K
# 3       SJCAM    16.0                                    4K, 1080P, 720P
# 4       GoPro    27.0                                        5120 × 2880
# ...

# %%
data['Price']=data['Price'].str.replace('₹','')

# %%
data['Price']=data['Price'].str.replace(',','')

# %%
data
# Out:
#         Brand  Pixels                                         Resolution  \
# 0    Insta360     NaN                                        3840 x 2160
# 1       GoPro    23.0                     Video 5.3K60 + 4K120, Wide FOV
# 2    Insta360    72.0                                               5.7K
# 3       SJCAM    16.0                                    4K, 1080P, 720P
# 4       GoPro    27.0                                        5120 × 2880
# ..        ...     ...                                                ...
# 395     GoPro    10.0                                         1440, 1080
# 396       dji     0.0                                                NaN
# 397     GoPro     NaN                                        5228 x 2624
# 398     SJCAM    16.0  4K (3840*2160) 30fps, 2.7K (2688*1520) 30fps, ...
# 399     SJCAM    20.0  3840 x 2160p at 30 fps (H.264/AVC, H.265/HEVC,...
#
#                                                Quality  \
# ...

# %%
Price=[]
for i in data["Price"]:
    Price.append(int(i))
print(Price)
data["Price"]=Price
# Out:
# [34990, 27490, 46990, 9999, 49990, 31990, 38990, 9498, 999, 11599, 44990, 6999, 64990, 34990, 27490, 38490, 46990, 9999, 49990, 31990, 13199, 41990, 54990, 9498, 999, 11599, 44990, 6999, 64990, 11599, 64990, 999, 51490, 4999, 58490, 1299, 899, 1299, 1280, 810, 1959, 2367, 6399, 6499, 1299, 9499, 799, 34990, 27490, 38490, 9999, 49990, 31990, 13199, 41990, 54990, 38990, 9498, 999, 11599, 44990, 6999, 64990, 11599, 64990, 999, 749, 51490, 4999, 58490, 1299, 899, 1299, 1280, 810, 1959, 6399, 6499, 1299, 9499, 799, 810, 9299, 899, 899, 899, 799, 1999, 1699, 799, 1859, 949, 1071, 28799, 31989, 47199, 2367, 1299, 2199, 2499, 2156, 34990, 27490, 38490, 46990, 9999, 49990, 31990, 13199, 41990, 54990, 38990, 9498, 999, 11599, 44990, 6999, 64990, 11599, 64990, 999, 51490, 4999, 1299, 899, 1299, 1280, 810, 1959, 2367, 6399, 6499, 1299, 9499, 799, 810, 9299, 899, 899, 899, 799, 1999, 1699, 799, 949, 1071, 28799, 31989, 2367, 1299, 10299, 1299, 2499, 2156, 1299, 899, 25999, 1196, 2699, 1199, 1449,
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              371 non-null    object
#  1   Pixels             379 non-null    float64
#  2   Resolution         376 non-null    object
#  3   Quality            384 non-null    object
#  4   Frames per second  396 non-null    object
#  5   Shutter            396 non-null    object
#  6   Sensor size        400 non-null    float64
#  7   Color              387 non-null    object
#  8   Camera size        400 non-null    object
#  9   Shooting modes     396 non-null    object
#  10  Price              400 non-null    int64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 34.5+ KB

# %%
data['Pixels']=data['Pixels'].replace({np.nan:0})

# %%
data.astype({'Pixels':float})
# Out:
#         Brand  Pixels                                         Resolution  \
# 0    Insta360     0.0                                        3840 x 2160
# 1       GoPro    23.0                     Video 5.3K60 + 4K120, Wide FOV
# 2    Insta360    72.0                                               5.7K
# 3       SJCAM    16.0                                    4K, 1080P, 720P
# 4       GoPro    27.0                                        5120 × 2880
# ..        ...     ...                                                ...
# 395     GoPro    10.0                                         1440, 1080
# 396       dji     0.0                                                NaN
# 397     GoPro     0.0                                        5228 x 2624
# 398     SJCAM    16.0  4K (3840*2160) 30fps, 2.7K (2688*1520) 30fps, ...
# 399     SJCAM    20.0  3840 x 2160p at 30 fps (H.264/AVC, H.265/HEVC,...
#
#                                                Quality  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              371 non-null    object
#  1   Pixels             400 non-null    float64
#  2   Resolution         376 non-null    object
#  3   Quality            384 non-null    object
#  4   Frames per second  396 non-null    object
#  5   Shutter            396 non-null    object
#  6   Sensor size        400 non-null    float64
#  7   Color              387 non-null    object
#  8   Camera size        400 non-null    object
#  9   Shooting modes     396 non-null    object
#  10  Price              400 non-null    int64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 34.5+ KB

# %%
data["Resolution"]=camera400["Resolution"]

# %%
data['Resolution']=data['Resolution'].replace({np.nan:0})

# %%
len(data["Resolution"].unique())
# Out:
# 58

# %%
data["Quality"].unique()
# Out:
# array(['5.7K', '5.3K, 4K', 'HDR', '4K/24FPS', '5120x2880', '3840x2160',
#        '2880x1920', 0, '4K/30FPS', '5.3K', '3840P', '720p', '1280x720',
#        '1080P, 720P', '1920x1080', '2560x1440', '1920*1080p', '4K, UHD',
#        '5.7k', '1080Full HD', '1080P', 'Full HD', '4K ,2.7K ,1080P ,720P',
#        '4K (3840*2160) 30FPS, 2K (2560*1440) 60/30FPS, 1080P 120/60/30FPS, 720P 120/60/30FPS',
#        '1440 Pixels', '2880p FHD', '1296P, 1080P', 'HD Resolution',
#        '4K ULTRA HD',
#        '360 Stitched Video Format:-Internal, 3840 x 1920 at 29.97 fps (56 Mb/s MP4 via H.264), 1920 x 960 at 29.97 fps (16 Mb/s MP4 via H.264).',
#        '1296P/30FPS', '1080', '1080P HD Quality', 'Ultra HD, MP4',
#        '1080 FHD', '4K/60FPS', '5K,4K ,2.7K ,1080P ,720P', 'Full Hd',
#        '4K, 2.7K, 1080P, 720P', 'FHD, 1080P, 720P'], dtype=object)

# %%
data['Quality']=data['Quality'].replace({np.nan:0,'2.7K':'2704x1520','2K':'2560x1440','4K':'3840x2160','3K':'2880x1920','5K':'5120x2880','1080p':'1920x1080','3840p':'3840x2160'})

# %%
data['Quality']=data['Quality'].replace({'HD':'1280x720','hd':'1280x720','FULL HD 4K':'3840x2160','FULL HD 4k':'3840x2160','FULLHD':'3840x2160','HDD':'1280x720','FULL HD':'3840x2160'})

# %%
data["Quality"]=data["Quality"].replace({'360 Stitched Video Format:-Internal, 3840 x 1920 at 29.97 fps (56 Mb/s MP4 via H.264), 1920 x 960 at 29.97 fps (16 Mb/s MP4 via H.264).':"3840x1920,1920x960"})

# %%
data["Quality"]=data["Quality"].replace({'1920*1080p':"1920x1080"})

# %%
for i in data["Quality"].unique():
    str(i).strip()
    print(i)
# Out:
# 5720x3016
# 4592x3440
# 3840x2160
# 5120x2880
# 2880x1920
# 0
# 1280x720
# 1920x1080
# 2560x1440
# 3840x1920
# 2304x1296

# %%
data
# Out:
#         Brand  Pixels                                         Resolution  \
# 0    Insta360     0.0                                        3840 x 2160
# 1       GoPro    23.0                     Video 5.3K60 + 4K120, Wide FOV
# 2    Insta360    72.0                                               5.7K
# 3       SJCAM    16.0                                    4K, 1080P, 720P
# 4       GoPro    27.0                                        5120 × 2880
# ..        ...     ...                                                ...
# 395     GoPro    10.0                                         1440, 1080
# 396       dji     0.0                                                  0
# 397     GoPro     0.0                                        5228 x 2624
# 398     SJCAM    16.0  4K (3840*2160) 30fps, 2.7K (2688*1520) 30fps, ...
# 399     SJCAM    20.0  3840 x 2160p at 30 fps (H.264/AVC, H.265/HEVC,...
#
#        Quality                 Frames per second Shutter  Sensor size  Color  \
# ...

# %%
data["Frames per second"]=data["Frames per second"].replace({'30FPS fpsVideo FormatA':30})

# %%
some1=[]
for i in some:
    j=str(i).split(",")[0].replace("5K ","").replace("MO","").replace("4k 30/2.7k 30 | 1920*1080 60 | 1920*1080 30 | 1280*720 120","120").replace("/30","").replace("4K","60").replace("720p","30")
    some1.append(j)
    print(j)
# Out:
# 30
# 60
# 60
# 24
# 120
# 50
# 240
# 0
# 30
# 24
# 30
# 30
# 10
# 24
# 30
# 30
# 10
# 10
# 50
# 120
# 100
# 30
# nan
# 30
# 29.7
# 30
# 10
# 30
# 30
# 30
# 30
# 30
# 30
# 60
# 24
# 30
# 30
# 30
# 60
# 29.97
# 32
# 30
# 60
# 30
# 60
# 30
# 24
# 120
# 10
#  60
# 60

# %%
l=list(data["Frames per second"].unique())
len(l)
len(some1)
# Out:
# 51

# %%
d={}
for i in range(len(l)):
    d[l[i]]=some1[i]
print(d)
# Out:
# {'30 fps': '30 ', '60 fps': '60 ', 60: '60', '24': '24', 120: '120', 50: '50', 240: '240', '0 fps': '0 ', '30FPS fps': '30 ', 24: '24', '720p fpsVideo FormatA': '30', 30: '30', 10: '10', '24 fps': '24 ', '30 fps fps': '30  ', '30fps fps': '30 ', '10, 60, 120 FPS fpsVideo FormatMO': '10', '10,60,120 Fps fps fps fpsVideo FormatMO': '10', '50 fpsVideo FormatA': '50', '120 fps': '120 ', '100 fps': '100 ', '30 fpsVideo FormatAVIOther Video FeaturesFULL HD ': '30 ', nan: 'nan', '1080P (1920*1080 ) 30FPS fps, 720P (1280*720) 60FPS fps, VGA ( 848*480) 60FPS fps, QVGA (640*480) 60FPS fpsVideo FormatVGA, AVI, JPG, MP4Other ': '30 ', '29.7 fpsVideo FormatMPEG-4 A': '29.7', '30 @ 4k fps, 60 @ 10800 fps , 120 @ 720p fpsVideo FormatA': '30 ', '10,60,120 Fps fpsVideo FormatMO': '10', '30 @ 4k fps fps fps, 60 @ 10800 fps fps fps, 120 @ 720p fp fpsVideo Format': '30   ', '30 Fps fpsVideo FormatMO': '30', '30 fps fpsVideo FormatMOVOther ': '30  ', '30FPS fpsVideo FormatM-JPEGOther Video FeaturesFull H
# ...

# %%
data["Frames per second"]=data["Frames per second"].replace(d)

# %%
data
# Out:
#         Brand  Pixels                                         Resolution  \
# 0    Insta360     0.0                                        3840 x 2160
# 1       GoPro    23.0                     Video 5.3K60 + 4K120, Wide FOV
# 2    Insta360    72.0                                               5.7K
# 3       SJCAM    16.0                                    4K, 1080P, 720P
# 4       GoPro    27.0                                        5120 × 2880
# ..        ...     ...                                                ...
# 395     GoPro    10.0                                         1440, 1080
# 396       dji     0.0                                                  0
# 397     GoPro     0.0                                        5228 x 2624
# 398     SJCAM    16.0  4K (3840*2160) 30fps, 2.7K (2688*1520) 30fps, ...
# 399     SJCAM    20.0  3840 x 2160p at 30 fps (H.264/AVC, H.265/HEVC,...
#
#        Quality Frames per second Shutter  Sensor size  Color  \
# ...

# %%
data['Shutter'].unique()
# Out:
# array(['Auto', 'Fixed', 'AutoShutter', 'no value', 'AutoOther',
#        'Electronic'], dtype=object)

# %%
data['Shutter']=data['Shutter'].replace({np.nan:'no value'})

# %%
width=[]
for i in tuple1:
    w=str(i).split(",")[0]
    width.append(w)
print(width)
# Out:
# ["'4.62 cm'", "'7.18 cm'", "'3.31 cm'", "'6 cm'", "'7.18 cm'", "'7.05 cm'", "'25.6 mm'", "'24.6 mm'", "'5 cm'", "'4.1 cm'", "'45 mm'", "'24.6 mm'", "'49 mm'", "'4.62 cm'", "'7.18 cm'", "'2.9 cm'", "'3.31 cm'", "'6 cm'", "'7.18 cm'", "'7.05 cm'", "'6.5 cm'", "'7.05 cm'", "'4.6 cm'", "'24.6 mm'", "'5 cm'", "'4.1 cm'", "'45 mm'", "'24.6 mm'", "'49 mm'", "'4.1 cm'", "'49 mm'", "'5 cm'", "'6.4 cm'", "'41 mm'", "'6.6 cm'", "'8 mm'", "'5 mm'", "'8 mm'", "'8 cm'", "'5 mm'", "'5 mm'", "'8 cm'", "'2.2 cm'", "'16 mm'", "'8 mm'", "'3.4 cm'", "'2.2 cm'", "'4.62 cm'", "'7.18 cm'", "'2.9 cm'", "'6 cm'", "'7.18 cm'", "'7.05 cm'", "'6.5 cm'", "'7.05 cm'", "'4.6 cm'", "'25.6 mm'", "'24.6 mm'", "'5 cm'", "'4.1 cm'", "'45 mm'", "'24.6 mm'", "'49 mm'", "'4.1 cm'", "'49 mm'", "'5 cm'", "'40 mm'", "'6.4 cm'", "'41 mm'", "'6.6 cm'", "'8 mm'", "'5 mm'", "'8 mm'", "'8 cm'", "'5 mm'", "'5 mm'", "'2.2 cm'", "'16 mm'", "'8 mm'", "'3.4 cm'", "'2.2 cm'", "'5 mm'", "'3 cm'", "'5 mm'", "'24 mm'", "'2.2 cm'", "'2.2 c
# ...

# %%
height=[]
for i in tuple1:
    h=str(i).split(",")[1]
    height.append(w)
print(height)
# Out:
# ["'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'", "'5 mm'
# ...

# %%
depth=[]
for i in tuple1:
    d=str(i).split(",")[2]
    depth.append(d)
print(depth)
# Out:
# [" '2.8 cm'", " '3.36 cm'", " '4.6 cm'", " '28 mm'", " '3.36 cm'", " '4.42 cm'", " '23.2 mm'", " '24.6 mm'", " '3.8 cm'", " '6.25 cm'", " '29 mm'", " '24.6 mm'", " '29 mm'", " '2.8 cm'", " '3.36 cm'", " '4.8 cm'", " '4.6 cm'", " '28 mm'", " '3.36 cm'", " '4.42 cm'", " '2.5 cm'", " '4.42 cm'", " '3.31 cm'", " '24.6 mm'", " '3.8 cm'", " '6.25 cm'", " '29 mm'", " '24.6 mm'", " '29 mm'", " '6.25 cm'", " '29 mm'", " '3.8 cm'", " '4 cm'", " '59.2 mm'", " '2.9 cm'", " '4.5 mm'", " '4 mm'", " '4.5 mm'", " '4.5 cm'", " '8 mm'", " '24.6 mm'", " '4.5 mm'", " '2 cm'", " '6 mm'", " '4.5 mm'", " '6.8 cm'", " '2.2 cm'", " '2.8 cm'", " '3.36 cm'", " '4.8 cm'", " '28 mm'", " '3.36 cm'", " '4.42 cm'", " '2.5 cm'", " '4.42 cm'", " '3.31 cm'", " '23.2 mm'", " '24.6 mm'", " '3.8 cm'", " '6.25 cm'", " '29 mm'", " '24.6 mm'", " '29 mm'", " '6.25 cm'", " '29 mm'", " '3.8 cm'", " '30 mm'", " '4 cm'", " '59.2 mm'", " '2.9 cm'", " '4.5 mm'", " '4 mm'", " '4.5 mm'", " '4.5 cm'", " '8 mm'", " '24.6 mm'", " '2 cm
# ...

# %%
weight=[]
for i in tuple1:
    we=str(i).split(",")[3]
    weight.append(we)
print(weight)
# Out:
# [" '0.149 kg'", " '0.131 kg'", " '180 g'", " '115 g'", " '260 g'", " '110 g'", " '0.135 kg'", " '70 g'", " '10 g'", " '80 g'", " '260 g'", " '70 g'", " '260 g'", " '0.149 kg'", " '0.131 kg'", " '500 g'", " '180 g'", " '115 g'", " '260 g'", " '110 g'", " '65 g'", " '110 g'", " '180 g'", " '70 g'", " '10 g'", " '80 g'", " '260 g'", " '70 g'", " '260 g'", " '80 g'", " '260 g'", " '10 g'", " '0.116 kg'", " '420 g'", " '500 g'", " '50 g'", " '100 g'", " '50 g'", " '50 g'", " '500 g'", " '150 g'", " '50 g'", " '40 g'", " '310 g'", " '50 g'", " '42 g'", " '48 g'", " '0.149 kg'", " '0.131 kg'", " '500 g'", " '115 g'", " '260 g'", " '110 g'", " '65 g'", " '110 g'", " '180 g'", " '0.135 kg'", " '70 g'", " '10 g'", " '80 g'", " '260 g'", " '70 g'", " '260 g'", " '80 g'", " '260 g'", " '10 g'", " '100 g'", " '0.116 kg'", " '420 g'", " '500 g'", " '50 g'", " '100 g'", " '50 g'", " '50 g'", " '500 g'", " '150 g'", " '40 g'", " '310 g'", " '50 g'", " '42 g'", " '48 g'", " '500 g'", " '34 g'", " '50
# ...

# %%
for i in range(len(weight)):
    if "kg" in weight[i]:
        weight[i]=float(weight[i].replace(" kg","").replace("'",""))*1000
    else:
        weight[i]=float(weight[i].replace(" g","").replace("'",""))

# %%
for i in weight:
    print(type(i))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# ...

# %%
for i in range(len(depth)):
    if "cm" in depth[i]:
        depth[i]=float(depth[i].replace(" cm","").replace("'",""))*10
    elif "inch" in depth[i]:
        depth[i]=float(depth[i].replace(" inch","").replace("'",""))*25.4
    else:
        depth[i]=float(depth[i].replace(" mm","").replace("'",""))

# %%
depth
# Out:
# [28.0,
#  33.6,
#  46.0,
#  28.0,
#  33.6,
#  44.2,
#  23.2,
#  24.6,
#  38.0,
#  62.5,
#  29.0,
#  24.6,
#  29.0,
#  28.0,
#  33.6,
#  48.0,
#  46.0,
#  28.0,
#  33.6,
#  44.2,
#  25.0,
#  44.2,
#  33.1,
#  24.6,
#  38.0,
#  62.5,
#  29.0,
#  24.6,
#  29.0,
#  62.5,
#  29.0,
#  38.0,
#  40.0,
#  59.2,
#  29.0,
#  4.5,
#  4.0,
#  4.5,
#  45.0,
#  8.0,
#  24.6,
#  4.5,
#  20.0,
#  6.0,
#  4.5,
#  68.0,
#  22.0,
#  28.0,
#  33.6,
#  48.0,
#  28.0,
#  33.6,
#  44.2,
#  25.0,
#  44.2,
#  33.1,
#  23.2,
#  24.6,
#  38.0,
#  62.5,
#  29.0,
#  24.6,
#  29.0,
#  62.5,
#  29.0,
#  38.0,
#  30.0,
#  40.0,
#  59.2,
#  29.0,
#  4.5,
#  4.0,
#  4.5,
#  45.0,
#  8.0,
#  24.6,
#  20.0,
#  6.0,
#  4.5,
#  68.0,
#  22.0,
#  8.0,
#  30.0,
#  4.0,
#  24.0,
#  22.0,
#  22.0,
#  20.0,
#  24.6,
#  18.0,
#  246.0,
#  80.0,
#  30.0,
#  189.0,
#  22.3,
#  80.00999999999999,
#  4.5,
#  22.0,
#  8.0,
#  30.0,
#  50.0,
#  28.0,
#  33.6,
#  48.0,
#  46.0,
#  28.0,
#  33.6,
#  44.2,
#  25.0,
#  44.2,
#  33.1,
# ...

# %%
for i in range(len(height)):
    height[i]=float(height[i].replace(" mm","").replace("'",""))
height
# Out:
# [5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
# ...

# %%
for i in range(len(width)):
    if "cm" in width[i]:
        width[i]=float(width[i].replace(" cm","").replace("'",""))*10
    elif "inch" in width[i]:
        width[i]=float(width[i].replace(" inch","").replace("'",""))*25.4
    else:
        width[i]=float(width[i].replace(" mm","").replace("'",""))

# %%
width
# Out:
# [46.2,
#  71.8,
#  33.1,
#  60.0,
#  71.8,
#  70.5,
#  25.6,
#  24.6,
#  50.0,
#  41.0,
#  45.0,
#  24.6,
#  49.0,
#  46.2,
#  71.8,
#  29.0,
#  33.1,
#  60.0,
#  71.8,
#  70.5,
#  65.0,
#  70.5,
#  46.0,
#  24.6,
#  50.0,
#  41.0,
#  45.0,
#  24.6,
#  49.0,
#  41.0,
#  49.0,
#  50.0,
#  64.0,
#  41.0,
#  66.0,
#  8.0,
#  5.0,
#  8.0,
#  80.0,
#  5.0,
#  5.0,
#  80.0,
#  22.0,
#  16.0,
#  8.0,
#  34.0,
#  22.0,
#  46.2,
#  71.8,
#  29.0,
#  60.0,
#  71.8,
#  70.5,
#  65.0,
#  70.5,
#  46.0,
#  25.6,
#  24.6,
#  50.0,
#  41.0,
#  45.0,
#  24.6,
#  49.0,
#  41.0,
#  49.0,
#  50.0,
#  40.0,
#  64.0,
#  41.0,
#  66.0,
#  8.0,
#  5.0,
#  8.0,
#  80.0,
#  5.0,
#  5.0,
#  22.0,
#  16.0,
#  8.0,
#  34.0,
#  22.0,
#  5.0,
#  30.0,
#  5.0,
#  24.0,
#  22.0,
#  22.0,
#  29.8,
#  24.6,
#  32.0,
#  246.0,
#  60.0,
#  30.0,
#  106.0,
#  39.0,
#  39.878,
#  80.0,
#  22.0,
#  50.0,
#  5.0,
#  4.0,
#  46.2,
#  71.8,
#  29.0,
#  33.1,
#  60.0,
#  71.8,
#  70.5,
#  65.0,
#  70.5,
#  46.0,
#  25.6,
# ...

# %%
del data["Resolution"]

# %%
data.head()
# Out:
#       Brand  Pixels    Quality Frames per second Shutter  Sensor size  Color  \
# 0  Insta360     0.0  5720x3016               30     Auto     0.000000  Black
# 1     GoPro    23.0  4592x3440               60     Auto     0.434783  Black
# 2  Insta360    72.0  3840x2160                60    Auto     0.000000  Black
# 3     SJCAM    16.0  3840x2160                24    Auto     0.000000  Black
# 4     GoPro    27.0  5120x2880                60    Auto     0.000000  Black
#
#                                      Camera size  \
# 0   ('4.62 cm', '11.3 cm', '2.8 cm', '0.149 kg')
# 1  ('7.18 cm', '5.08 cm', '3.36 cm', '0.131 kg')
# 2      ('3.31 cm', '11.4 cm', '4.6 cm', '180 g')
# 3             ('6 cm', '4 cm', '28 mm', '115 g')
# 4     ('7.18 cm', '5.08 cm', '3.36 cm', '260 g')
#
#                                       Shooting modes  Price
# 0  Still, VideoPortsType-CWireless ConnectivityYe...  34990
# 1        Super Photo, HDR, Standard and RAWPortsHDMI  27490
# ...

# %%
data["Camera Weight"]=weight
data["Camera Height"]=height
data["Camera Depth"]=depth
data["Camera Width"]=width

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              371 non-null    object
#  1   Pixels             400 non-null    float64
#  2   Quality            400 non-null    object
#  3   Frames per second  400 non-null    object
#  4   Shutter            400 non-null    object
#  5   Sensor size        400 non-null    float64
#  6   Color              387 non-null    object
#  7   Camera size        400 non-null    object
#  8   Shooting modes     396 non-null    object
#  9   Price              400 non-null    int64
#  10  Camera Weight      400 non-null    float64
#  11  Camera Height      400 non-null    float64
#  12  Camera Depth       400 non-null    float64
#  13  Camera Width       400 non-null    float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 43.9+ KB

# %%
del data["Camera size"]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              371 non-null    object
#  1   Pixels             400 non-null    float64
#  2   Quality            400 non-null    object
#  3   Frames per second  400 non-null    object
#  4   Shutter            400 non-null    object
#  5   Sensor size        400 non-null    float64
#  6   Color              387 non-null    object
#  7   Shooting modes     396 non-null    object
#  8   Price              400 non-null    int64
#  9   Camera Weight      400 non-null    float64
#  10  Camera Height      400 non-null    float64
#  11  Camera Depth       400 non-null    float64
#  12  Camera Width       400 non-null    float64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 40.8+ KB

# %%
data["Brand"]=data["Brand"].replace({np.nan:0})

# %%
data["Brand"]=data["Brand"].replace({0:"SJCAM"})

# %%
sum(data["Brand"].isnull())
# Out:
# 0

# %%
data["Color"].mode()
# Out:
# 0    Black
# dtype: object

# %%
data["Color"]=data["Color"].replace({np.nan:"Black"})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              400 non-null    object
#  1   Pixels             400 non-null    float64
#  2   Quality            400 non-null    object
#  3   Frames per second  400 non-null    object
#  4   Shutter            400 non-null    object
#  5   Sensor size        400 non-null    float64
#  6   Color              400 non-null    object
#  7   Shooting modes     396 non-null    object
#  8   Price              400 non-null    int64
#  9   Camera Weight      400 non-null    float64
#  10  Camera Height      400 non-null    float64
#  11  Camera Depth       400 non-null    float64
#  12  Camera Width       400 non-null    float64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 40.8+ KB

# %%
data["Shooting modes"].mode()
# Out:
# 0    Times Laps, Video, Photo ModesPortsUSB-C Port
# dtype: object

# %%
data["Shooting modes"]=data["Shooting modes"].replace({np.nan:"Times Laps, Video, Photo ModesPortsUSB-C Port"})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              400 non-null    object
#  1   Pixels             400 non-null    float64
#  2   Quality            400 non-null    object
#  3   Frames per second  400 non-null    object
#  4   Shutter            400 non-null    object
#  5   Sensor size        400 non-null    float64
#  6   Color              400 non-null    object
#  7   Shooting modes     400 non-null    object
#  8   Price              400 non-null    int64
#  9   Camera Weight      400 non-null    float64
#  10  Camera Height      400 non-null    float64
#  11  Camera Depth       400 non-null    float64
#  12  Camera Width       400 non-null    float64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 40.8+ KB

# %%
fpss=[]
for i in ["Frames per second"]:
    fpss.append(i)

# %%
for i in data["Frames "]
# Out:
#         Brand  Pixels    Quality  Frames per second Shutter  Sensor size  \
# 0    Insta360     0.0  5720x3016               30.0    Auto     0.000000
# 1       GoPro    23.0  4592x3440               60.0    Auto     0.434783
# 2    Insta360    72.0  3840x2160               60.0    Auto     0.000000
# 3       SJCAM    16.0  3840x2160               24.0    Auto     0.000000
# 4       GoPro    27.0  5120x2880               60.0    Auto     0.000000
# ..        ...     ...        ...                ...     ...          ...
# 395     GoPro    10.0  2560x1440               60.0    Auto     0.434783
# 396       dji     0.0          0                0.0   Fixed     0.000000
# 397     GoPro     0.0  5120x2880               24.0    Auto     0.000000
# 398     SJCAM    16.0  3840x2160               30.0   Fixed     0.000000
# 399     SJCAM    20.0  3840x2160               30.0    Auto     0.000000
#
#      Color                                     Shooting modes  Price  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              400 non-null    object
#  1   Pixels             400 non-null    float64
#  2   Quality            400 non-null    object
#  3   Frames per second  400 non-null    object
#  4   Shutter            400 non-null    object
#  5   Sensor size        400 non-null    float64
#  6   Color              400 non-null    object
#  7   Shooting modes     400 non-null    object
#  8   Price              400 non-null    int64
#  9   Camera Weight      400 non-null    float64
#  10  Camera Height      400 non-null    float64
#  11  Camera Depth       400 non-null    float64
#  12  Camera Width       400 non-null    float64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 40.8+ KB

# %%
data["Frames per second"]=data["Frames per second"].replace({"nan":0})

# %%
fpss=[]
for i in data["Frames per second"]:
    fpss.append(float(i))
print(fpss)
data["Frames per second"]=fpss
# Out:
# [30.0, 60.0, 60.0, 24.0, 60.0, 120.0, 50.0, 240.0, 0.0, 30.0, 60.0, 240.0, 60.0, 30.0, 60.0, 120.0, 60.0, 24.0, 60.0, 120.0, 24.0, 120.0, 60.0, 240.0, 0.0, 30.0, 60.0, 240.0, 60.0, 30.0, 60.0, 0.0, 24.0, 30.0, 120.0, 30.0, 30.0, 10.0, 60.0, 30.0, 120.0, 30.0, 30.0, 60.0, 30.0, 24.0, 30.0, 30.0, 60.0, 120.0, 24.0, 60.0, 120.0, 24.0, 120.0, 60.0, 50.0, 240.0, 0.0, 30.0, 60.0, 240.0, 60.0, 30.0, 60.0, 0.0, 30.0, 24.0, 30.0, 120.0, 30.0, 30.0, 10.0, 60.0, 30.0, 120.0, 30.0, 60.0, 30.0, 24.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 10.0, 30.0, 10.0, 30.0, 50.0, 30.0, 120.0, 100.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 60.0, 120.0, 60.0, 24.0, 60.0, 120.0, 24.0, 120.0, 60.0, 50.0, 240.0, 0.0, 30.0, 60.0, 240.0, 60.0, 30.0, 60.0, 0.0, 24.0, 30.0, 30.0, 30.0, 10.0, 60.0, 30.0, 120.0, 30.0, 30.0, 60.0, 30.0, 24.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 10.0, 30.0, 30.0, 50.0, 30.0, 120.0, 30.0, 30.0, 0.0, 30.0, 30.0, 30.0, 30.0, 30.0, 29.7, 0.0, 30.0, 30.0, 30.0, 30.0, 30.0, 10
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              400 non-null    object
#  1   Pixels             400 non-null    float64
#  2   Quality            400 non-null    object
#  3   Frames per second  400 non-null    float64
#  4   Shutter            400 non-null    object
#  5   Sensor size        400 non-null    float64
#  6   Color              400 non-null    object
#  7   Shooting modes     400 non-null    object
#  8   Price              400 non-null    int64
#  9   Camera Weight      400 non-null    float64
#  10  Camera Height      400 non-null    float64
#  11  Camera Depth       400 non-null    float64
#  12  Camera Width       400 non-null    float64
# dtypes: float64(7), int64(1), object(5)
# memory usage: 40.8+ KB

# %%
res=[]
for i in data["Quality"]:
    res.append(str(i).split("x"))
res
# Out:
# [['5720', '3016'],
#  ['4592', '3440'],
#  ['3840', '2160'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['3840', '2160'],
#  ['2880', '1920'],
#  ['5120', '2880'],
#  ['0'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['5720', '3016'],
#  ['4592', '3440'],
#  ['4592', '3440'],
#  ['3840', '2160'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['3840', '2160'],
#  ['3840', '2160'],
#  ['3840', '2160'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['0'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['0'],
#  ['5120', '2880'],
#  ['3840', '2160'],
#  ['3840', '2160'],
#  ['1280', '720'],
#  ['1280', '720'],
#  ['1280', '720'],
#  ['1920', '1080'],
#  ['1920', '1080'],
#  ['1280', '720'],
#  ['1280', '720'],
#  ['2560', '1440'],
#  ['5120', '2880'],
#  ['1280', '720'],
#  ['3840', '2160'],
#  ['1280', '720'],
#  ['5720', '3016'],
#  ['4592', '3440'],
# ...

# %%
for i in range(len(res)):
    if "0" in res[i]:
        res[i].append("0")
res
# Out:
# [['5720', '3016'],
#  ['4592', '3440'],
#  ['3840', '2160'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['3840', '2160'],
#  ['2880', '1920'],
#  ['5120', '2880'],
#  ['0', '0'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['5720', '3016'],
#  ['4592', '3440'],
#  ['4592', '3440'],
#  ['3840', '2160'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['3840', '2160'],
#  ['3840', '2160'],
#  ['3840', '2160'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['0', '0'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['3840', '2160'],
#  ['5120', '2880'],
#  ['0', '0'],
#  ['5120', '2880'],
#  ['3840', '2160'],
#  ['3840', '2160'],
#  ['1280', '720'],
#  ['1280', '720'],
#  ['1280', '720'],
#  ['1920', '1080'],
#  ['1920', '1080'],
#  ['1280', '720'],
#  ['1280', '720'],
#  ['2560', '1440'],
#  ['5120', '2880'],
#  ['1280', '720'],
#  ['3840', '2160'],
#  ['1280', '720'],
#  ['5720', '3016'],
# ...

# %%
res1=[]
for i in range(len(res)):
    res1.append((int(res[i][0])*int(res[i][1]))/1000000)

# %%
data["Resolution(MP)"]=res1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              400 non-null    object
#  1   Pixels             400 non-null    float64
#  2   Quality            400 non-null    object
#  3   Frames per second  400 non-null    float64
#  4   Shutter            400 non-null    object
#  5   Sensor size        400 non-null    float64
#  6   Color              400 non-null    object
#  7   Shooting modes     400 non-null    object
#  8   Price              400 non-null    int64
#  9   Camera Weight      400 non-null    float64
#  10  Camera Height      400 non-null    float64
#  11  Camera Depth       400 non-null    float64
#  12  Camera Width       400 non-null    float64
#  13  Resolution(MP)     400 non-null    float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 43.9+ KB

# %% [markdown]
# # Converting cleaned data into csv

# %%
data.to_csv("clean data.csv",index=False)
